# %% [markdown]
# ### COLLOBORATIVE FILTERING

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.metrics.pairwise import cosine_similarity
import operator
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth',-1)

# %% [markdown]
# ### LOAD DATA

# %%
# Data Januari
data_jan=pd.read_excel('Peminjaman buku 2016.xls',sheetname='Jan',header=3)
data_jan=data_jan[3:]
data_jan=data_jan.reset_index(drop=True)
print ('data Januari')
data_jan.head()
# Out:
# data Januari
#     No    Tanggal ID Anggota          Nama Anggota Prodi   ID Buku  \
# 0  4.0  6-Jan-16   02.00283   Tulus P. Simanjuntak  NaN   03.01737
# 1  5.0  18-Jan-16  02.00283   Tulus P. Simanjuntak  NaN   10.06667
# 2  6.0  20-Jan-16  02.00283   Tulus P. Simanjuntak  NaN   03.01737
# 3  7.0  26-Jan-16  02.00292   Edwin Swandi Sijabat  NaN   15.00050
# 4  8.0  26-Jan-16  02.00292   Edwin Swandi Sijabat  NaN   14.00418
#
#                                            Judul Aktifitas  \
# 0  Sistem Operasi : bagian-bagian dan prinsip-pr  Borrow
# 1  RHCE: Red Hat Certified Engineer Linux: Study  Return
# 2  Sistem Operasi : bagian-bagian dan prinsip-pr  Return
# 3  Problem Solving and Program Design in C        Borrow
# 4  Teori Bahasa dan Otomata                       Borrow
#
#       Tanggal Kembali  Keterangan
# 0  20-Jan-16 17:06:08 NaN
# 1  18-Jan-16 14:09:07 NaN
# 2  20-Jan-16 17:06:08 NaN
# 3  6-Apr-16 08:50:42  NaN
# 4  NaN                NaN

# %%
# Data Feb
data_feb=pd.read_excel('Peminjaman buku 2016.xls',sheetname='Feb',header=3)
data_feb=data_jan[3:]
data_feb=data_feb.reset_index(drop=True)
print ('data Februari')
data_feb.head()
# Out:
# data Februari
#      No    Tanggal ID Anggota              Nama Anggota Prodi   ID Buku  \
# 0  7.0   26-Jan-16  02.00292   Edwin Swandi Sijabat      NaN   15.00050
# 1  8.0   26-Jan-16  02.00292   Edwin Swandi Sijabat      NaN   14.00418
# 2  9.0   6-Apr-16   02.00292   Edwin Swandi Sijabat      NaN   15.00050
# 3  10.0  25-Jan-16  02.00293   Gerry Italiano Wowilling  NaN   03.03343
# 4  11.0  19-Feb-16  02.00293   Gerry Italiano Wowilling  NaN   03.03343
#
#                                       Judul Aktifitas     Tanggal Kembali  \
# 0  Problem Solving and Program Design in C   Borrow    6-Apr-16 08:50:42
# 1  Teori Bahasa dan Otomata                  Borrow    NaN
# 2  Problem Solving and Program Design in C   Return    6-Apr-16 08:50:42
# 3  Cambridge Preparation for the TOEFL Test  Borrow    19-Feb-16 21:24:18
# 4  Cambridge Preparation for the TOEFL Test  Return    19-Feb-16 21:24:18
#
#    Keterangan
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
data_peminjaman=pd.concat([data_jan,data_feb])
print "jumlah data:\t", len(data_peminjaman)
data_peminjaman.head()
# Out:
# jumlah data:	1459
#     No    Tanggal ID Anggota          Nama Anggota Prodi   ID Buku  \
# 0  4.0  6-Jan-16   02.00283   Tulus P. Simanjuntak  NaN   03.01737
# 1  5.0  18-Jan-16  02.00283   Tulus P. Simanjuntak  NaN   10.06667
# 2  6.0  20-Jan-16  02.00283   Tulus P. Simanjuntak  NaN   03.01737
# 3  7.0  26-Jan-16  02.00292   Edwin Swandi Sijabat  NaN   15.00050
# 4  8.0  26-Jan-16  02.00292   Edwin Swandi Sijabat  NaN   14.00418
#
#                                            Judul Aktifitas  \
# 0  Sistem Operasi : bagian-bagian dan prinsip-pr  Borrow
# 1  RHCE: Red Hat Certified Engineer Linux: Study  Return
# 2  Sistem Operasi : bagian-bagian dan prinsip-pr  Return
# 3  Problem Solving and Program Design in C        Borrow
# 4  Teori Bahasa dan Otomata                       Borrow
#
#       Tanggal Kembali  Keterangan
# 0  20-Jan-16 17:06:08 NaN
# 1  18-Jan-16 14:09:07 NaN
# 2  20-Jan-16 17:06:08 NaN
# 3  6-Apr-16 08:50:42  NaN
# 4  NaN                NaN

# %%
data_peminjaman_id=data_peminjaman[['ID Anggota','ID Buku','Judul']]
print "jumlah data:\t", len(data_peminjaman_id) 
data_peminjaman_id.head()
# Out:
# jumlah data:	1459
#   ID Anggota   ID Buku                                          Judul
# 0  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 1  02.00283   10.06667  RHCE: Red Hat Certified Engineer Linux: Study
# 2  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 3  02.00292   15.00050  Problem Solving and Program Design in C
# 4  02.00292   14.00418  Teori Bahasa dan Otomata

# %% [markdown]
# ### HILANGKAN NAN DAN DUPLIKAT
# #### HILANGKAN NAN

# %%
#hilangkan nan
#data_jan=data_jan.dropna(how='any').head(10)
data_peminjaman_id=data_peminjaman_id.dropna(how='any')
print "jumlah data:\t", len(data_peminjaman_id) 
data_peminjaman_id.head(10)
# Out:
# jumlah data:	1449
#   ID Anggota   ID Buku                                          Judul
# 0  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 1  02.00283   10.06667  RHCE: Red Hat Certified Engineer Linux: Study
# 2  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 3  02.00292   15.00050  Problem Solving and Program Design in C
# 4  02.00292   14.00418  Teori Bahasa dan Otomata
# 5  02.00292   15.00050  Problem Solving and Program Design in C
# 6  02.00293   03.03343  Cambridge Preparation for the TOEFL Test
# 7  02.00293   03.03343  Cambridge Preparation for the TOEFL Test
# 8  02.00303   02.00766  Don't Sweat the small stuff in Love
# 9  02.00303   02.00766  Don't Sweat the small stuff in Love

# %%
#HILANGKAN DUPLIKAT
data_peminjaman_id=data_peminjaman_id.loc[~data_peminjaman_id.duplicated(['ID Anggota','ID Buku'])==True]
print "jumlah data:\t", len(data_peminjaman_id) 
data_peminjaman_id.head(10)
# Out:
# jumlah data:	309
#    ID Anggota         ID Buku  \
# 0   02.00283   03.01737
# 1   02.00283   10.06667
# 3   02.00292   15.00050
# 4   02.00292   14.00418
# 6   02.00293   03.03343
# 8   02.00303   02.00766
# 11  02.00304   15.5202.009020
# 12  02.00304   13.07412
# 13  02.00304   15.5200.009018
# 14  02.00304   14.00069
#
#                                                    Judul
# 0   Sistem Operasi : bagian-bagian dan prinsip-pr
# 1   RHCE: Red Hat Certified Engineer Linux: Study
# 3   Problem Solving and Program Design in C
# 4   Teori Bahasa dan Otomata
# 6   Cambridge Preparation for the TOEFL Test
# 8   Don't Sweat the small stuff in Love
# 11  Supernova: Kesatria, Putri, & Bintang Jatuh
# 12  Rectoverso
# 13  Supernova: Petir
# 14  Filosofi Kopi: Kumpulan cerita dan prosa satu dekade

# %% [markdown]
# ### DATA JIKA DIMASUKKAN ATRIBUT AKTIVITAS

# %% [markdown]
# Weighted Rating (WR) = (v/(v+m).R)+(m(v+m).C)
#
# where,
#
# - v is the number of votes for the movie
# - m is the minimum votes required to be listed in the chart
# - R is the average rating of the movie
# - C is the mean vote across the whole report

# %%
data_peminjaman_aktivitas=data_peminjaman.copy()
data_peminjaman_aktivitas=data_peminjaman_aktivitas[['ID Anggota','ID Buku','Judul','Aktifitas']]
data_peminjaman_aktivitas=data_peminjaman_aktivitas.dropna(how='any')#drp na
event_type = {
   'Borrow': 1.0,#pinjam
   'Return': 0.0, #kembalikan
   'Renew': 2.0# Perpanjangan  
}

data_peminjaman_aktivitas['score'] = data_peminjaman_aktivitas['Aktifitas'].apply(lambda x: event_type[x])
print "jumlah data:\t", len(data_peminjaman_aktivitas) 
data_peminjaman_aktivitas.head(10)
# Out:
# jumlah data:	1449
#   ID Anggota   ID Buku                                          Judul  \
# 0  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 1  02.00283   10.06667  RHCE: Red Hat Certified Engineer Linux: Study
# 2  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 3  02.00292   15.00050  Problem Solving and Program Design in C
# 4  02.00292   14.00418  Teori Bahasa dan Otomata
# 5  02.00292   15.00050  Problem Solving and Program Design in C
# 6  02.00293   03.03343  Cambridge Preparation for the TOEFL Test
# 7  02.00293   03.03343  Cambridge Preparation for the TOEFL Test
# 8  02.00303   02.00766  Don't Sweat the small stuff in Love
# 9  02.00303   02.00766  Don't Sweat the small stuff in Love
#
#   Aktifitas  score
# 0  Borrow    1.0
# 1  Return    0.0
# 2  Return    0.0
# 3  Borrow    1.0
# 4  Borrow    1.0
# 5  Return    0.0
# 6  Borrow    1.0
# 7  Return    0.0
# 8  Renew     2.0
# 9  Borrow    1.0

# %%
#Hilanngkan Duplikat
data_peminjaman_aktivitas=data_peminjaman_aktivitas.loc[
    ~data_peminjaman_aktivitas.duplicated(['ID Anggota','ID Buku'])==True]
data_peminjaman_aktivitas=data_peminjaman_aktivitas.reset_index(drop=True)
print "jumlah data:\t", len(data_peminjaman_aktivitas) 
data_peminjaman_aktivitas.head(10)
# Out:
# jumlah data:	309
#   ID Anggota         ID Buku  \
# 0  02.00283   03.01737
# 1  02.00283   10.06667
# 2  02.00292   15.00050
# 3  02.00292   14.00418
# 4  02.00293   03.03343
# 5  02.00303   02.00766
# 6  02.00304   15.5202.009020
# 7  02.00304   13.07412
# 8  02.00304   15.5200.009018
# 9  02.00304   14.00069
#
#                                                   Judul Aktifitas  score
# 0  Sistem Operasi : bagian-bagian dan prinsip-pr         Borrow    1.0
# 1  RHCE: Red Hat Certified Engineer Linux: Study         Return    0.0
# 2  Problem Solving and Program Design in C               Borrow    1.0
# 3  Teori Bahasa dan Otomata                              Borrow    1.0
# 4  Cambridge Preparation for the TOEFL Test              Borrow    1.0
# 5  Don't Sweat the small stuff in Love                   Renew     2.0
# 6  Supernova: Kesatria, Putri, & Bintang Jatuh           Borrow    1.0
# 7  Rectoverso                                            Borrow    1.0
# ...

# %% [markdown]
# ### POPULARITY

# %%
buku_popular=data_peminjaman_aktivitas.groupby('Judul'
                    )['score'].sum().sort_values(ascending=False).reset_index()
buku_popular=buku_popular.rename(columns={"score": "popularity"})
buku_popular.head()
# Out:
#                                                            Judul  popularity
# 0  Kalkulus Edisi Kesembilan Jilid 1                              49.0
# 1  Practice Exercises for the TOEFL                               27.0
# 2  Metoda Statistika                                              16.0
# 3  Longman preparation course for the TOEFL test: The paper test  13.0
# 4  Ilmu peluang dan statistika untuk insinyur da                  13.0

# %% [markdown]
# ### PERHATIKAN
# karena ada ID buku berbeda tetapi memiliki judul sama, maka lebih baik di groupkan berdasarkan Judul
# - Bandingkan hasil berikut

# %%
data_y=data_peminjaman_aktivitas.copy()
data_y.head()
#tambahkan kondisi
# Out:
#   ID Anggota   ID Buku                                          Judul  \
# 0  02.00283   03.01737  Sistem Operasi : bagian-bagian dan prinsip-pr
# 1  02.00283   10.06667  RHCE: Red Hat Certified Engineer Linux: Study
# 2  02.00292   15.00050  Problem Solving and Program Design in C
# 3  02.00292   14.00418  Teori Bahasa dan Otomata
# 4  02.00293   03.03343  Cambridge Preparation for the TOEFL Test
#
#   Aktifitas  score
# 0  Borrow    1.0
# 1  Return    0.0
# 2  Borrow    1.0
# 3  Borrow    1.0
# 4  Borrow    1.0

# %% [markdown]
# TERLIHAT BAHWA JIKA KITA GROUP KAN BERDASARKAN ID, MAKA BUKU YANG POPULAR adalah
#     : 15.4966.008784: Basis Data

# %%
print data_y.groupby(['ID Buku'])['score'].sum().sort_values(ascending=False).head(10)
data_y[data_y['ID Buku']=='15.4966.008784'].head(10)
# Out:
# ID Buku
# 15.4966.008784    3.0
# 12.07111          2.0
# 15.00076          2.0
# 11.06976          2.0
# 14.00466          2.0
# 14.00467          2.0
# 15.00079          2.0
# 07.06135          2.0
# 15.00395          2.0
# 14.00470          2.0
# Name: score, dtype: float64
#     ID Anggota         ID Buku       Judul Aktifitas  score
# 40   11113001   15.4966.008784  Basis Data  Borrow    1.0
# 289  11S14047   15.4966.008784  Basis Data  Renew     2.0

# %%
import seaborn as sns
df2=buku_popular.copy()
#df2.iloc[5].plot(kind='bar')
g = sns.barplot(data=df2.head(10),x='Judul',y='popularity')
g.set_xticklabels(g.get_xticklabels(),rotation=60)
#g.map(sns.distplot, "Judul")
sns.plt.show()

# %% [markdown]
# ### PROSES COLLOBORATIVE FILTERING

# %% [markdown]
# ### Implemeting the Nearest Neighbor Model
# - https://beckernick.github.io/music_recommender/
# - https://github.com/topics/recommendation-system?o=desc&s=updated
# - http://www.data-mania.com/blog/recommendation-system-python/
# - https://github.com/haritha1313/book-recommender
# - https://github.com/bradleypallen/keras-movielens-cf
# - https://blog.statsbot.co/recommendation-system-algorithms-ba67f39ac9a3

# %% [markdown]
# ### Fitting the Model

# %%
from scipy.sparse import csr_matrix
import numpy as np

# %% [markdown]
# ### Making Recommendation
#
# And we’re finally ready to make some recommendations!

# %%
data_x=buku_popular.copy()
print data_x.head()
data_y=data_peminjaman_aktivitas.copy()
print "jumlah buku:\t", len(data_y)
#data_y.head()
# Out:
#                                                            Judul  popularity
# 0  Kalkulus Edisi Kesembilan Jilid 1                              49.0
# 1  Practice Exercises for the TOEFL                               27.0
# 2  Metoda Statistika                                              16.0
# 3  Longman preparation course for the TOEFL test: The paper test  13.0
# 4  Ilmu peluang dan statistika untuk insinyur da                  13.0
# jumlah buku:	309

# %%
data_z=data_y.merge(data_x, on='Judul').sort(['score'],ascending=False)
#data_z=data_z.rename(columns={"score1": "popularity"})
data_z.head()

data_w=data_z[['ID Anggota','Judul','score','popularity']]
data_w.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     ID Anggota                                          Judul  score  \
# 308  08.00999   The C Programming  Language : second edition   2.0
# 201  12S15048   Kalkulus Edisi Kesembilan Jilid 1              2.0
# 118  02.00265   Human-Computer Interaction                     2.0
# 210  14S15006   Kalkulus Edisi Kesembilan Jilid 1              2.0
# 216  14S15062   Kalkulus Edisi Kesembilan Jilid 1              2.0
#
#      popularity
# 308  2.0
# 201  49.0
# 118  2.0
# 210  49.0
# 216  49.0

# %%
n_users = data_w['ID Anggota'].unique().shape[0]
n_items = data_w['Judul'].unique().shape[0]
print str(n_users) + ' users'
print str(n_items) + ' items'
# Out:
# 166 users
# 165 items

# %%
kalkulus_data = data_w.query('Judul == \'Kalkulus Edisi Kesembilan Jilid 1\'')
kalkulus_data.duplicated()
data_w[data_w.duplicated(['ID Anggota','Judul'])]

#hilangkan duplikat 
if not data_w[data_w.duplicated(['ID Anggota', 'Judul'])].empty:
    initial_rows = data_w.shape[0]

    print 'Initial dataframe shape {0}'.format(data_w.shape)
    data_w = data_w.drop_duplicates(['ID Anggota', 'Judul'])
    current_rows = data_w.shape[0]
    print 'New dataframe shape {0}'.format(data_w.shape)
    print 'Removed {0} rows'.format(initial_rows - current_rows)

print (len(data_w))
print kalkulus_data.shape[0]
kalkulus_data.head()
# Out:
# 302
# 37
#     ID Anggota                              Judul  score  popularity
# 201  12S15048   Kalkulus Edisi Kesembilan Jilid 1  2.0    49.0
# 210  14S15006   Kalkulus Edisi Kesembilan Jilid 1  2.0    49.0
# 216  14S15062   Kalkulus Edisi Kesembilan Jilid 1  2.0    49.0
# 221  11S15024   Kalkulus Edisi Kesembilan Jilid 1  2.0    49.0
# 203  12S15050   Kalkulus Edisi Kesembilan Jilid 1  2.0    49.0

# %%
#n=1
#wide_artist_data.iloc[n:n+1]
#wide_artist_data[wide_artist_data.index=='101 Tips & Trik komputer plus internet']

# %%
# Nearest N

wide_artist_data = data_w.pivot(index = 'Judul', columns = 'ID Anggota', values = 'score').fillna(0)
wide_artist_data_sparse = csr_matrix(wide_artist_data.values)


from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(wide_artist_data_sparse)

print 'Shape=',wide_artist_data.shape

query_index = 1 #shape-1
distances, indices = model_knn.kneighbors(wide_artist_data.iloc[query_index, :].reshape(1, -1), n_neighbors = 5)

for i in range(0, len(distances.flatten())):
    if i == 0:
        print 'Rekomendasi Buku {0}:\n'.format(wide_artist_data.index[query_index])
    else:
        print '{0}: {1}, with distance of {2}:'.format(i, wide_artist_data.index[indices.flatten()[i]], distances.flatten()[i])
# Out:
# Shape= (165, 166)
# Rekomendasi Buku 1700 Bank Soal Bimbingan Pemantapan Matematika untuk SMA/MA:
#
# 1: 1700 Bank Soal Bimbingan Pemantapan Matematika untuk SMA/MA, with distance of 0.0:
# 2: Principles of Engineering Thermodynamics., with distance of 1.0:
# 3: Principles of Program Analysis, with distance of 1.0:
# 4: Probability & statistics for engineers & scie, with distance of 1.0:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:15: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %% [markdown]
# ## BAGUS
# - https://github.com/mahermalaeb/recommendations-amazon-dataset/blob/master/cf_recommendation_clothing_dataset.ipynb

# %% [markdown]
# ### IMPLEMENTING USER BASED MODEL

# %%
data_user_base=data_peminjaman_aktivitas.copy()
data_user_base=data_user_base[['ID Anggota','Judul','score']]
#data_user_base.head()


data_user_base=data_user_base.loc[
    ~data_user_base.duplicated(['ID Anggota','Judul'])==True]
data_user_base=data_user_base.reset_index(drop=True)
print "jumlah data:\t", len(data_user_base) 
data_user_base.head(10)
# Out:
# jumlah data:	302
#   ID Anggota                                                 Judul  score
# 0  02.00283   Sistem Operasi : bagian-bagian dan prinsip-pr         1.0
# 1  02.00283   RHCE: Red Hat Certified Engineer Linux: Study         0.0
# 2  02.00292   Problem Solving and Program Design in C               1.0
# 3  02.00292   Teori Bahasa dan Otomata                              1.0
# 4  02.00293   Cambridge Preparation for the TOEFL Test              1.0
# 5  02.00303   Don't Sweat the small stuff in Love                   2.0
# 6  02.00304   Supernova: Kesatria, Putri, & Bintang Jatuh           1.0
# 7  02.00304   Rectoverso                                            1.0
# 8  02.00304   Supernova: Petir                                      1.0
# 9  02.00304   Filosofi Kopi: Kumpulan cerita dan prosa satu dekade  1.0

# %%
data2=data_user_base.pivot(index='ID Anggota', columns='Judul', values='score').fillna(0)
data2.head()
# Out:
# Judul       101 Tips & Trik komputer plus internet  \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
#
# Judul       1700 Bank Soal Bimbingan Pemantapan Matematika untuk SMA/MA  \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
#
# Judul       2000 (two thousand)solved problems in discret  \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
#
# Judul       2010 BPM and worksflow handbook  \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
#
# Judul       36 jam belajar komputer Microsoft SQL server   \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
#
# Judul       4 model tes TOEFL: Memuat 600 soal TOEFL leng  \
# ID Anggota
# 02.00113    0.0
# 02.00227    0.0
# 02.00241    0.0
# 02.00261    0.0
# 02.00265    0.0
# ...

# %%
#data2[1:2]['101 Tips & Trik komputer plus internet']
data2=data2.to_dict()

# %%
data2.keys()
# Out:
# [u'Oxford English for Information technology : s',
#  u'Margareth Thatcher: Wanita Besi',
#  u'William Shakespeare: Sastrawan Ternama',
#  u'Hacking: The Art of Exploitation',
#  u'Data Structures and Alghorithm Analysis in C.',
#  u'Dasar - dasar manajemen',
#  u'Supernova: Petir',
#  u'MySQL',
#  u'Complete Electronics: Self Teaching Guide with projects',
#  u'Siaga dan sukses jelang ujian nasional fisika SMA/MA',
#  u'1700 Bank Soal Bimbingan Pemantapan Matematika untuk SMA/MA',
#  u'Oxford English for Information technology : t',
#  u'Software Requirements',
#  u'Filosofi Kopi: Kumpulan cerita dan prosa satu dekade',
#  u'Swanderella ',
#  u'Strategy maps: converting intangible assets i',
#  u'Career Paths: Software Engineering',
#  u'Career Paths: Environmental Science',
#  u'Numerical Analysis',
#  u'Pulang',
#  u'The advanced grammar book',
#  u'101 Tips & Trik komputer plus internet',
#  u'The Fifth Discipline: The Art & Practice of The Learning Organisation',
# ...

# %%
# Returns the Pearson correlation coefficient for p1 and p2
from math import sqrt
def sim_pearson(prefs,p1,p2):
    si={}
    for item in prefs[p1]:
          if item in prefs[p2]: 
            si[item]=1
 # Find the number of elements
    n=len(si)
 # if they are no ratings in common, return 0
    if n==0: return 0
 # Add up all the preferences
    sum1=sum([prefs[p1][it] for it in si])
    sum2=sum([prefs[p2][it] for it in si])
 # Sum up the squares
    sum1Sq=sum([pow(prefs[p1][it],2) for it in si])
    sum2Sq=sum([pow(prefs[p2][it],2) for it in si])
 # Sum up the products
    pSum=sum([prefs[p1][it]*prefs[p2][it] for it in si])
 # Calculate Pearson score
    num=pSum-(sum1*sum2/n)
    den=sqrt((sum1Sq-pow(sum1,2)/n)*(sum2Sq-pow(sum2,2)/n))
    if den==0: return 0
    r=num/den
    return r


#print sim_pearson(data2,'02.00283','02.00283')
#data2=pd.DataFrame

#for item in data2['02.00283']

# %%
sim_pearson(data2,'Career Paths: Software Engineering','Career Paths: Environmental Science')
# Out:
# -0.0060606060606060606
